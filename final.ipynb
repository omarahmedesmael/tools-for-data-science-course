# %% [markdown]
# # final week of the tools of data science course

# %% [markdown]
# ### this is the final assignment of the course and I hope you find it well made

# %% [markdown]
# #### this is a list of DATA science languages
# |-|Language|
# |-|------------|
# |1|Python|
# |2|Julia|
# |3|R|
# |4|Visual basic|
# |5|SQL|
# |6|Scala|
# |7|Java|

# %% [markdown]
# ###### this is a list of DATA science libraries
# |Language|Library|Usage|
# |------------|------------------|-----------------------|
# |Python|Pandas|scientific computing|
# |Python|NumPY|scientific computing|
# |Python|MatPlotLib|visualization|
# |Python|sea born|visualization|
# |Python|scikit-learn|Machine learning|
# |Python|Keras|Deep learning|
# |Python|tensor frow|Deep learning|
# |Scala|Vegas|visualization|
# |R|ggplot2|visualization|

# %% [markdown]
# ##### this is a list of Data science tools
# | |tool|example|
# |---|-----------------------|----------------------------|
# |1|Programming language|Python and R|
# |2|IDEs|Rstudio and JupyterLab|
# |3|version control|Github and GitLab|

# %% [markdown]
# ##### this is an introduction to arthmetic expressions
# |symbol|meaning|
# |-----------|-------------|
# |+|adding|
# |-|subtracting|
# |* |multiplying|
# |/|dividing|
# |=|equals|
# |<>|does not equal|
# |<|smaller than|
# |>|bigger than|

# %%
import random
num01 = random.randint(0,1000)
num02 = random.randint(0,1000)
# first we will add the two numbers
FirstTest = num01 + num02
print(FirstTest)
# secondly we will multiply both numbers
SecondTest = num01 * num02
print(SecondTest)
# Out:
# 1360
# 361276

# %%
# in the third test we will make a code that converts minutes to hours
import random
minutesNum = random.randint(0,60000)
hoursNum = minutesNum/60
print(hoursNum)
# Out:
# 597.4666666666667

# %% [markdown]
# ## this document was made by Omar Ahmed aka عمر احمد

# %% [markdown]
# ![image.png](attachment:624061f6-26bd-4b73-9d89-2ffbb0fe88a2.png)
